# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?

# %%
df=pd.read_csv('C:/Users/HP/Desktop/data science/WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# This dataset contains 1470 rows and 35 columns

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# there are two types of data in this data set

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# we can clearly visualize that there is no missing values

# %%
#checking for value counts
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Age
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: count, dtype: int64
#
#
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
#
#
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
#
#
# DailyRate
# 691     6
# 408     5
# 530     5
# 1329    5
# 1082    5
#        ..
# 650     1
# 279     1
# 316     1
# 314     1
# 628     1
# Name: count, Length: 886, dtype: int64
#
#
# Department
# Research & Development    961
# Sales                     446
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicate values are present

# %% [markdown]
# # Statistical analysis

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# 1.This gives the statistical summary of numerical columns.
# The summary of the dataset looks perfect since there is no negative or invalid values are present.
# 2.In this dataset count of all columns are same,which means there is no missing values are present.
# 3.The median(50%) is greater than mean which means skewness is preset
# 4.By summarizing the data there is diff between 75% and max Which means not muchoutliers are present.

# %% [markdown]
#  Standard deviation(std) for the fields "EmployeeCount" and ."StandardHours" are ZERO. Hence these fields does not add value, hence they can be removed.

# %%
df = df.drop(['EmployeeCount','Over18'], axis = 1)

# %% [markdown]
# Seperating categorical and numerical

# %%
#checking for categorical columns
cat_cols=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        cat_cols.append(i)
print('Categorical columns:',cat_cols)
# Out:
# Categorical columns: ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']

# %%
#checking for numerical columns
num_cols=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        num_cols.append(i)
print('Numerical columns:',num_cols)
# Out:
# Numerical columns: ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %% [markdown]
# # Univariate Analysis:

# %%
ax=sns.countplot(x='Attrition',data=df)

# %%
ax=sns.countplot(x='Department',data=df)

# %%
ax=sns.countplot(x='BusinessTravel',data=df)

# %%
ax=sns.countplot(x='EducationField',data=df)

# %%
ax=sns.countplot(x='Gender',data=df)

# %%
plt.figure(figsize=(20,8))
ax=sns.countplot(x='JobRole',data=df)

# %%
ax=sns.countplot(x='Department',data=df)

# %%
ax=sns.countplot(x='MaritalStatus',data=df)

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='BusinessTravel',y='MonthlyIncome',hue='Attrition',data=df)
# Out:
# <Axes: xlabel='BusinessTravel', ylabel='MonthlyIncome'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(y='JobSatisfaction',x='Attrition',data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='JobSatisfaction'>

# %%
fig, ax = plt.subplots(figsize=(25,9))
sns.countplot(data=df,x="JobRole",hue="Attrition", ax=ax )
# Out:
# <Axes: xlabel='JobRole', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Department',hue='Attrition',data=df)
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Gender',hue='Attrition',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# 0                        2  ...                        1             80
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df['Attrition']=df['Attrition'].replace({'No':0,'Yes':1})

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
df['Gender']=df['Gender'].map({"Male":0,"Female":1})

# %%
df.head(2)
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
#
#    EnvironmentSatisfaction  ...  RelationshipSatisfaction  StandardHours  \
# 0                        2  ...                         1             80
# 1                        3  ...                         4             80
#
#    StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                 0                  8                     0                1
# 1                 1                 10                     3                3
#
#   YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# ...

# %%
cat_cols
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
#applying label encoding to categoricl column
from sklearn.preprocessing import LabelEncoder
label_encoder={}
for column in cat_cols:
    label_encoder[column]=LabelEncoder()
    df[column]=label_encoder[column].fit_transform(df[column])

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  ...  \
# 0          2               1               1                        2  ...
# 1          1               1               2                        3  ...
# 2          2               4               4                        4  ...
# 3          4               1               5                        4  ...
# 4          1               3               7                        1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
plt.figure(figsize = (25,50), facecolor = 'Yellow')
plotnumber = 1

for column in df:
    if plotnumber <=35:
        ax = plt.subplot(7,5,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %% [markdown]
# # checking for outliers

# %%
plt.figure(figsize=(20,15))
graph=1
for column in df:
    if graph<33:
        ax=plt.subplot(7,5,graph)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
        graph +=1
        plt.tight_layout()

# %%
from scipy.stats import zscore
out_features=df[['MonthlyIncome','PerformanceRating','StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion']]
z=np.abs(zscore(out_features))
z
# Out:
#       MonthlyIncome  PerformanceRating  StockOptionLevel  TotalWorkingYears  \
# 0          0.108350           0.426230          0.932014           0.421642
# 1          0.291719           2.346151          0.241988           0.164511
# 2          0.937654           0.426230          0.932014           0.550208
# 3          0.763634           0.426230          0.932014           0.421642
# 4          0.644858           0.426230          0.241988           0.678774
# ...             ...                ...               ...                ...
# 1465       0.835451           0.426230          0.241988           0.735447
# 1466       0.741140           0.426230          0.241988           0.293077
# 1467       0.076690           2.346151          0.241988           0.678774
# 1468       0.236474           0.426230          0.932014           0.735447
# 1469       0.445978           0.426230          0.932014           0.678774
#
# ...

# %%
#thresold=3
np.where(z>3)
# Out:
# (array([  45,   62,   62,   63,   64,   85,   98,   98,  110,  123,  123,
#          126,  126,  126,  178,  187,  190,  190,  218,  231,  237,  237,
#          270,  270,  281,  326,  386,  401,  411,  425,  425,  427,  445,
#          466,  473,  477,  535,  561,  584,  592,  595,  595,  595,  624,
#          653,  653,  677,  701,  716,  746,  749,  752,  799,  838,  861,
#          861,  875,  894,  914,  914,  918,  922,  926,  937,  956,  962,
#          976,  976, 1008, 1024, 1043, 1078, 1086, 1086, 1093, 1111, 1116,
#         1116, 1135, 1138, 1138, 1156, 1184, 1221, 1223, 1242, 1295, 1301,
#         1301, 1303, 1327, 1331, 1351, 1401, 1414, 1430], dtype=int64),
#  array([7, 5, 7, 6, 7, 3, 3, 5, 7, 6, 7, 3, 5, 7, 7, 3, 5, 6, 7, 6, 5, 7,
#         3, 5, 6, 7, 7, 3, 5, 5, 7, 7, 3, 6, 5, 5, 7, 5, 7, 5, 3, 5, 7, 3,
#         5, 7, 5, 7, 6, 6, 5, 7, 7, 7, 5, 7, 7, 3, 5, 7, 5, 7, 7, 7, 3, 5,
#         6, 7, 7, 6, 3, 7, 5, 7, 7, 5, 3, 5, 5, 5, 7, 7, 3, 7, 7, 7, 7, 3,
# ...

# %%
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (1393, 33)

# %%
print("old df",df.shape)
print("new df",df1.shape)
# Out:
# old df (1470, 33)
# new df (1393, 33)

# %%
print("Data loss percentage-",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage- 5.238095238095238

# %%
df1.skew()
# Out:
# Age                         0.466048
# Attrition                   1.812948
# BusinessTravel             -1.433386
# DailyRate                  -0.015366
# Department                  0.187561
# DistanceFromHome            0.955957
# Education                  -0.293474
# EducationField              0.546641
# EmployeeNumber              0.020712
# EnvironmentSatisfaction    -0.322066
# Gender                      0.415419
# HourlyRate                 -0.028322
# JobInvolvement             -0.501241
# JobLevel                    1.116566
# JobRole                    -0.379928
# JobSatisfaction            -0.343818
# MaritalStatus              -0.159095
# MonthlyIncome               1.533080
# MonthlyRate                 0.030727
# NumCompaniesWorked          1.039124
# OverTime                    0.953608
# PercentSalaryHike           0.800017
# PerformanceRating           1.930917
# RelationshipSatisfaction   -0.296152
# StandardHours               0.000000
# ...

# %%
df1['YearsSinceLastPromotion']=np.cbrt(df['YearsSinceLastPromotion'])
df1['YearsAtCompany']=np.cbrt(df1['YearsAtCompany'])
df1['TotalWorkingYears']=np.cbrt(df1['TotalWorkingYears'])
df1['NumCompaniesWorked']=np.cbrt(df1['NumCompaniesWorked'])
df1['MonthlyIncome']=np.cbrt(df1['MonthlyIncome'])
df1['BusinessTravel']=np.cbrt(df1['BusinessTravel'])

# %% [markdown]
# # Plotting Heatmap(correlation)

# %%
df1_corr=df1.corr().abs()
plt.figure(figsize=(20,15))
sns.heatmap(df1_corr,annot=True,annot_kws={'size':6})
plt.show()

# %% [markdown]
# As we can see from the heat map, there is a higgh correlation between MonthlyIncome and JobLevel. Therefore, dropping JobLevel.

# %% [markdown]
# Seperating features and label

# %%
x= df1.drop(['Attrition',"EmployeeNumber","HourlyRate","MonthlyRate","PercentSalaryHike","StandardHours","YearsSinceLastPromotion"], axis=1)

# %%
y=df1['Attrition']

# %%
x.shape,y.shape
# Out:
# ((1393, 26), (1393,))

# %% [markdown]
# # Feature scaling using standard scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.533748        0.470352   0.735474    1.407558         -1.011663
# 1     1.439501       -0.214884  -1.305655   -0.496062         -0.145804
# 2     0.080871        0.470352   1.407583   -0.496062         -0.887969
# 3    -0.372006       -0.214884   1.454705   -0.496062         -0.764275
# 4    -1.051321        0.470352  -0.531861   -0.496062         -0.887969
# ...        ...             ...        ...         ...               ...
# 1388 -0.032348       -0.214884   0.194810   -0.496062          1.709606
# 1389  0.307309        0.470352  -0.477299   -0.496062         -0.393192
# 1390 -1.051321        0.470352  -1.613188   -0.496062         -0.640581
# 1391  1.439501       -0.214884   0.539545    1.407558         -0.887969
# 1392 -0.258787        0.470352  -0.440097   -0.496062         -0.145804
#
#       Education  EducationField  EnvironmentSatisfaction    Gender  \
# ...

# %% [markdown]
# # Variance inflation factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['features']=x.columns
vif
# Out:
#     VIF values                  features
# 0     1.848600                       Age
# 1     1.018226            BusinessTravel
# 2     1.021723                 DailyRate
# 3     2.000320                Department
# 4     1.013186          DistanceFromHome
# 5     1.062045                 Education
# 6     1.018298            EducationField
# 7     1.024009   EnvironmentSatisfaction
# 8     1.023752                    Gender
# 9     1.014969            JobInvolvement
# 10    8.125542                  JobLevel
# 11    1.958377                   JobRole
# 12    1.017568           JobSatisfaction
# 13    1.844608             MaritalStatus
# 14    8.370750             MonthlyIncome
# 15    1.291606        NumCompaniesWorked
# 16    1.028771                  OverTime
# 17    1.008885         PerformanceRating
# 18    1.020408  RelationshipSatisfaction
# 19    1.811512          StockOptionLevel
# 20    3.848318         TotalWorkingYears
# 21    1.025776     TrainingTimesLastYear
# ...

# %% [markdown]
# there is no multicolinearity By checking the vif values

# %% [markdown]
# # Finding the best RandomState

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    RFR=RandomForestClassifier()
    RFR.fit(x_train,y_train)
    pred=RFR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
        print("Best accuracy is",maxAccu,"at random state",maxRS)
# Out:
# Best accuracy is 0.8755980861244019 at random state 1
# Best accuracy is 0.8779904306220095 at random state 8
# Best accuracy is 0.8803827751196173 at random state 15
# Best accuracy is 0.8851674641148325 at random state 30
# Best accuracy is 0.8875598086124402 at random state 44
# Best accuracy is 0.8971291866028708 at random state 126

# %% [markdown]
# # classification Algorithms

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Random Forest classification model

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC=RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.8492822966507177
# [[346   1]
#  [ 62   9]]
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92       347
#            1       0.90      0.13      0.22        71
#
#     accuracy                           0.85       418
#    macro avg       0.87      0.56      0.57       418
# weighted avg       0.86      0.85      0.80       418

# %% [markdown]
# Accuracy for Randomforest classifier is 85%

# %% [markdown]
# # ExtraTreesClassifier

# %%
ET=ExtraTreesClassifier()
ET.fit(x_train,y_train)
predET=ET.predict(x_test)
print(accuracy_score(y_test,predET))
print(confusion_matrix(y_test,predET))
print(classification_report(y_test,predET))
# Out:
# 0.8444976076555024
# [[344   3]
#  [ 62   9]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       347
#            1       0.75      0.13      0.22        71
#
#     accuracy                           0.84       418
#    macro avg       0.80      0.56      0.57       418
# weighted avg       0.83      0.84      0.80       418

# %% [markdown]
# Accuracy of ExtraTreeClasifier is 84%

# %% [markdown]
# # logisticRegression

# %%
LR=LogisticRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
print(accuracy_score(y_test,predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# 0.861244019138756
# [[335  12]
#  [ 46  25]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92       347
#            1       0.68      0.35      0.46        71
#
#     accuracy                           0.86       418
#    macro avg       0.78      0.66      0.69       418
# weighted avg       0.84      0.86      0.84       418

# %% [markdown]
# Accuracy of Logistic Regression is 86%

# %% [markdown]
# # SVC

# %%
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.8588516746411483
# [[345   2]
#  [ 57  14]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       347
#            1       0.88      0.20      0.32        71
#
#     accuracy                           0.86       418
#    macro avg       0.87      0.60      0.62       418
# weighted avg       0.86      0.86      0.82       418

# %% [markdown]
# # AdaBoostClassifier

# %%
ada=AdaBoostClassifier()
ada.fit(x_train,y_train)
predada=ada.predict(x_test)
print(accuracy_score(y_test,predada))
print(confusion_matrix(y_test,predada))
print(classification_report(y_test,predada))
# Out:
# 0.861244019138756
# [[339   8]
#  [ 50  21]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       347
#            1       0.72      0.30      0.42        71
#
#     accuracy                           0.86       418
#    macro avg       0.80      0.64      0.67       418
# weighted avg       0.85      0.86      0.84       418

# %% [markdown]
# Accuracy of AdaBoost is 86%

# %% [markdown]
# # Bagging Classifier

# %%
BC=BaggingClassifier()
BC.fit(x_train,y_train)
predBC=BC.predict(x_test)
print(accuracy_score(y_test,predBC))
print(confusion_matrix(y_test,predBC))
print(classification_report(y_test,predBC))
# Out:
# 0.8564593301435407
# [[344   3]
#  [ 57  14]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       347
#            1       0.82      0.20      0.32        71
#
#     accuracy                           0.86       418
#    macro avg       0.84      0.59      0.62       418
# weighted avg       0.85      0.86      0.82       418

# %%
DT=DecisionTreeClassifier()
DT.fit(x_train,y_train)
predDT=DT.predict(x_test)
print(accuracy_score(y_test,predDT))
print(confusion_matrix(y_test,predDT))
print(classification_report(y_test,predDT))
# Out:
# 0.7679425837320574
# [[297  50]
#  [ 47  24]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       347
#            1       0.32      0.34      0.33        71
#
#     accuracy                           0.77       418
#    macro avg       0.59      0.60      0.60       418
# weighted avg       0.77      0.77      0.77       418

# %% [markdown]
# # Cross Validation

# %%
#cross validation of Random Forest
score=cross_val_score(RFC,x,y)
print("score")
print(score.mean())
print("Diff between acc_score and cross validation-",accuracy_score(y_test,predRFC)-score.mean())
# Out:
# score
# 0.8578582295453959
# Diff between acc_score and cross validation- -0.008575932894678173

# %%
#cross validation for Extratree classifier
score1=cross_val_score(ET,x,y)
print("score1")
print(score1.mean())
print("Diff between acc_score and cross validation-",accuracy_score(y_test,predET)-score1.mean())
# Out:
# score1
# 0.860016502926691
# Diff between acc_score and cross validation- -0.015518895271188549

# %%
#cross validarion for logistic regreesion
score2=cross_val_score(LR,x,y)
print("score2")
print(score2.mean())
print("Diff between acc_score and cross validation-",accuracy_score(y_test,predLR)-score2.mean())
# Out:
# score2
# 0.8750883164436193
# Diff between acc_score and cross validation- -0.013844297304863251

# %%
#cross validation for Ada boosting
score3=cross_val_score(ada,x,y)
print("score3")
print(score3.mean())
print("Diff between acc_score and cross validation-",accuracy_score(y_test,predada)-score3.mean())
# Out:
# score3
# 0.8686315463758026
# Diff between acc_score and cross validation- -0.007387527237046609

# %%
#cross validation for decision trees
score4=cross_val_score(DT,x,y)
print("score4")
print(score4.mean())
print("Diff between acc_score and cross validation-",accuracy_score(y_test,predDT)-score4.mean())
# Out:
# score4
# 0.781772001753436
# Diff between acc_score and cross validation- -0.013829418021378603

# %%
#cross validation for Bagging classifier
score5=cross_val_score(BC,x,y)
print("score5")
print(score5.mean())
print("Diff between acc_score and cross validation-",accuracy_score(y_test,predBC)-score5.mean())
# Out:
# score5
# 0.8406229854825817
# Diff between acc_score and cross validation- -0.07507274624813198

# %%
#cross validation for SVM
score6=cross_val_score(svc,x,y)
print("score6")
print(score6.mean())
print("Diff between acc_score and cross validation-",accuracy_score(y_test,predsvc)-score6.mean())
# Out:
# score6
# 0.8636136252288493
# Diff between acc_score and cross validation- -0.004761950587701014

# %% [markdown]
# Randon Forest classifier is best modelas the difference between accuracy and crossvalidation is least

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV
parameters={'criterion':['gini','entropy'],
             'random_state':[10,50,1200],
             'max_depth':[10,15],
            'n_jobs':[-2,-1,1],
        
           'n_estimators':[50,100,200,300]}

# %%
grid=GridSearchCV(RandomForestClassifier(),parameters,cv=5)

# %%
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 15],
#                          'n_estimators': [50, 100, 200, 300],
#                          'n_jobs': [-2, -1, 1],
#                          'random_state': [10, 50, 1200]})

# %%
grid.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 10,
#  'n_estimators': 300,
#  'n_jobs': -2,
#  'random_state': 10}

# %%
Final_model=RandomForestClassifier(criterion='entropy',max_depth=15,n_estimators=300,n_jobs=-2,random_state=1500)
Final_model.fit(x_train,y_train)
pred=Final_model.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 85.16746411483254

# %% [markdown]
# Lets check auc for best model hyper parameter tuning

# %%
from sklearn import metrics
fpr,tpr,thresholds=metrics.roc_curve(y_test,pred)
roc_auc=metrics.auc(fpr,tpr)
display=metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,roc_auc=roc_auc,estimator_name=Final_model)
display.plot()

# %%
import joblib
joblib.dump(Final_model,"HR Employee Attrition.pkl")
# Out:
# ['HR Employee Attrition.pkl']

# %% [markdown]
# Predicting the saved model

# %%
model=joblib.load("HR Employee Attrition.pkl")
prediction=model.predict(x_test)

# %%
a=np.array(y_test)
df=pd.DataFrame()
df["prediction"]=prediction
df["original"]=a
df
# Out:
#      prediction  original
# 0             0         0
# 1             0         0
# 2             0         1
# 3             0         0
# 4             0         0
# ..          ...       ...
# 413           0         0
# 414           0         0
# 415           0         0
# 416           1         1
# 417           0         0
#
# [418 rows x 2 columns]
